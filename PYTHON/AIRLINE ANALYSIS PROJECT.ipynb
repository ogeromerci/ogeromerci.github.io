# %% [markdown]
# **AIRLINE ANALYSIS PROJECT**

# %%
# This is a python project aimed at finding the best deals for flights by understanding how airline prices change based on various aspects

# %%
'''
The columns present in this dara are:
- `miles`: miles traveled through the flight
- `passengers`: number of passengers on the flight
- `delay`: take-off delay in minutes
- `inflight_meal`: is there a meal included in the flight?
- `inflight_entertainment`: are there free entertainment systems for each seat?
- `inflight_wifi`: is there complimentary wifi on the flight?
- `day_of_week`: day of the week of the flight
- `weekend`: did this flight take place on a weekend?
- `coach_price`: the average price paid for a coach ticket
- `firstclass_price`: the average price paid for first-class seats
- `hours`: how many hours the flight took
- `redeye`: was this flight a redeye (overnight)?
'''
# Out:
# '\nThe columns present in this dara are:\n- `miles`: miles traveled through the flight\n- `passengers`: number of passengers on the flight\n- `delay`: take-off delay in minutes\n- `inflight_meal`: is there a meal included in the flight?\n- `inflight_entertainment`: are there free entertainment systems for each seat?\n- `inflight_wifi`: is there complimentary wifi on the flight?\n- `day_of_week`: day of the week of the flight\n- `weekend`: did this flight take place on a weekend?\n- `coach_price`: the average price paid for a coach ticket\n- `firstclass_price`: the average price paid for first-class seats\n- `hours`: how many hours the flight took\n- `redeye`: was this flight a redeye (overnight)?\n'

# %%
# import the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels
import matplotlib.pyplot as plt
import math

# %%
# read in the data
flight_data = pd.read_csv("C:\\Users\\Lenovo\\OneDrive\\Documents\\UADSL\\PYTHON\DATA\\flight_data.csv")
flight_data
# Out:
#         miles  passengers  delay inflight_meal inflight_entertainment  \
# 0         792         172      0            No                    Yes
# 1        3163         214      0            No                    Yes
# 2        1832         212      0            No                    Yes
# 3         925         213      0            No                    Yes
# 4         967         217      0           Yes                    Yes
# ...       ...         ...    ...           ...                    ...
# 129775    674         217   1487            No                    Yes
# 129776   2125         208   1479            No                    Yes
# 129777   1702         220   1501            No                    Yes
# 129778   2709         205   1484            No                    Yes
# 129779   4005         214   1490            No                    Yes
#
#        inflight_wifi day_of_week redeye weekend  coach_price  \
# 0                Yes      Sunday    Yes     Yes      338.820
# ...

# %%
# dataframe called coach_price
flight_data["coach_price"]
# Out:
# 0         338.820
# 1         472.655
# 2         351.960
# 3         387.835
# 4         374.735
#            ...
# 129775    383.240
# 129776    397.825
# 129777    380.980
# 129778    485.185
# 129779    446.395
# Name: coach_price, Length: 129780, dtype: float64

# %%
## Task 2
print(np.mean(flight_data.delay[flight_data.delay == 8]))
print(np.median(flight_data.delay[flight_data.delay == 8]))

sns.histplot(flight_data.coach_price[flight_data.hours == 8])

plt.show()
plt.clf()
# Out:
# 8.0
# 8.0
# C:\Users\Lenovo\anaconda3\ANACONDA30\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Visualizing the kinds of delays 
sns.histplot(flight_data.delay[flight_data.delay <= 500])
plt.show()
plt.clf()
# Out:
# C:\Users\Lenovo\anaconda3\ANACONDA30\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# visualizing the relationship between the coach prices and first-class proces.
perc = 0.1
flight_sub = flight_data.sample(n = int(flight_data.shape[0]*perc))

sns.lmplot(x = "coach_price", y = "firstclass_price", data = flight_sub, line_kws={'color': 'black'}, lowess=True)
plt.show()
plt.clf()

# %%
# relationship between coach price and the inflight meals

# %%
sns.histplot(flight_data,x = "coach_price",hue = flight_data.inflight_meal)
plt.show
# Out:
# C:\Users\Lenovo\anaconda3\ANACONDA30\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# relationship between the coach price and the inflight entertainment
sns.histplot(flight_data, x ="coach_price", hue = flight_data.inflight_entertainment)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\ANACONDA30\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# relationship between caoch price and the inflight wifi
sns.histplot(flight_data, x = "coach_price", hue = flight_data.inflight_wifi)
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\ANACONDA30\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# How the number of passengers change in relation to the length of flight
sns.lmplot(x = "hours", y = "passengers", data = flight_sub, x_jitter = 0.25, scatter_kws={"s": 5, "alpha":0.9}, fit_reg = False)
plt.show()
plt.clf()

# %%
sns.Implot?
# Out:
# Object `sns.Implot` not found.

# %% [markdown]
# **MULTIVARIATE ANALYSIS**

# %%
'''
The sns.Implot plots the linear regression models in seabbron. It helps visualize the relationship between two models by fitting a linear regression and displaying the scatter plots of the data
The syntax of sns.Implot is:
sns.Implot(x, y, data, hue = None, col = None, row = None, palette = None, markers = None, scatter = True, fit-reg = True, ci = .95, legend = True, height = 5, aspect = 1)
1. x = the name of the column of the dataframe to be plotted in the x-axis
2. y = the name of the column of the dataframe to be plotted in the y_axis
3. data = The dataframe the contains the data that you want to plot
4. hue = optional. grouping variable that will produce different regression lines and colors for the subsets of the data
5. col, row = optional. Variables that define the subset of the data plotted across different columns or rowns in a grid of plots
6. Markers : Optional: Marker style for scatter plots points
7. Scatter : Default is True. If set to False, the regression line will not be drawn
8. ci. size of the confidence interval for the regression line. The default is 0.95
9. legend : whether to add the legend. The default is True
10. Aspect : The aspect ration of each facet. The default s 1, so the plot is square

# %%
sns.lmplot(x = "coach_price", y = "firstclass_price", hue = "weekend", data = flight_sub, fit_reg = True, legend = True)
plt.show()
plt.clf()

# %%
sns.lmplot(x = 'coach_price', y = 'firstclass_price', hue = 'weekend', data = flight_sub, fit_reg=False)
plt.show()
plt.clf()

# %%
# How the coach prices change for the redeyes and the non-redeyes on each day of the week 
sns.boxplot(x = "day_of_week", y = "coach_price", hue = "redeye", data = flight_data)
plt.show()
plt.clf()
