# %% [markdown]
# ## Reading a csv

# %%
import pandas as pd

# %% [markdown]
# #### 1. Read a csv file

# %%
df = pd.read_csv('Country-data.csv')

# %% [markdown]
# ##### 4. Inspect the head of the file

# %%
df.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp
# 0       9.44        56.2       5.82    553
# 1       4.49        76.3       1.65   4090
# 2      16.10        76.5       2.89   4460
# 3      22.40        60.1       6.16   3530
# 4       1.44        76.8       2.13  12200

# %% [markdown]
# ##### 4. Inspect the tail of the file

# %%
## brings the last five rows if you don't specify
df.tail()
# Out:
#        country  child_mort  exports  health  imports  income  inflation  \
# 162    Vanuatu        29.2     46.6    5.25     52.7    2950       2.62
# 163  Venezuela        17.1     28.5    4.91     17.6   16500      45.90
# 164    Vietnam        23.3     72.0    6.84     80.2    4490      12.10
# 165      Yemen        56.3     30.0    5.18     34.4    4480      23.60
# 166     Zambia        83.1     37.0    5.89     30.9    3280      14.00
#
#      life_expec  total_fer   gdpp
# 162        63.0       3.50   2970
# 163        75.4       2.47  13500
# 164        73.1       1.95   1310
# 165        67.5       4.67   1310
# 166        52.0       5.40   1460

# %% [markdown]
# #### 3. How many rows do we have in this dataset

# %%
df.shape
# Out:
# (167, 10)

# %% [markdown]
# #### 4. What are the column headers on this file

# %%
df.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %%
# List the columns
for name in df.columns:
    print(name)
# Out:
# country
# child_mort
# exports
# health
# imports
# income
# inflation
# life_expec
# total_fer
# gdpp

# %%
# Enumerate the columns 
for index,column_name in enumerate(df.columns):
    print(index,column_name)
# Out:
# 0 country
# 1 child_mort
# 2 exports
# 3 health
# 4 imports
# 5 income
# 6 inflation
# 7 life_expec
# 8 total_fer
# 9 gdpp

# %%
# Enumerate the columns 
for num,column_name in enumerate(df.columns):
    print(num,column_name)
# Out:
# 0 country
# 1 child_mort
# 2 exports
# 3 health
# 4 imports
# 5 income
# 6 inflation
# 7 life_expec
# 8 total_fer
# 9 gdpp

# %% [markdown]
# ### 5. Getting Summary Statistics

# %%
df.describe()
# Out:
#        child_mort     exports      health     imports         income  \
# count  167.000000  167.000000  167.000000  167.000000     167.000000
# mean    38.270060   41.108976    6.815689   46.890215   17144.688623
# std     40.328931   27.412010    2.746837   24.209589   19278.067698
# min      2.600000    0.109000    1.810000    0.065900     609.000000
# 25%      8.250000   23.800000    4.920000   30.200000    3355.000000
# 50%     19.300000   35.000000    6.320000   43.300000    9960.000000
# 75%     62.100000   51.350000    8.600000   58.750000   22800.000000
# max    208.000000  200.000000   17.900000  174.000000  125000.000000
#
#         inflation  life_expec   total_fer           gdpp
# count  167.000000  167.000000  167.000000     167.000000
# mean     7.781832   70.555689    2.947964   12964.155689
# std     10.570704    8.893172    1.513848   18328.704809
# min     -4.210000   32.100000    1.150000     231.000000
# 25%      1.810000   65.300000    1.795000    1330.000000
# ...

# %% [markdown]
# ### 5. Are there any missing values in the dataset

# %%
## this null method returns a boolean value 
df[['inflation','income']].isnull()
# Out:
#      inflation  income
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# ..         ...     ...
# 162      False   False
# 163      False   False
# 164      False   False
# 165      False   False
# 166      False   False
#
# [167 rows x 2 columns]

# %%
df.isna()
# Out:
#      country  child_mort  exports  health  imports  income  inflation  \
# 0      False       False    False   False    False   False      False
# 1      False       False    False   False    False   False      False
# 2      False       False    False   False    False   False      False
# 3      False       False    False   False    False   False      False
# 4      False       False    False   False    False   False      False
# ..       ...         ...      ...     ...      ...     ...        ...
# 162    False       False    False   False    False   False      False
# 163    False       False    False   False    False   False      False
# 164    False       False    False   False    False   False      False
# 165    False       False    False   False    False   False      False
# 166    False       False    False   False    False   False      False
#
#      life_expec  total_fer   gdpp
# 0         False      False  False
# 1         False      False  False
# ...

# %%
salaries = [df['income']]
salaries.sort()
salaries.avg()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 3
#       1 salaries = [df['income']]
#       2 salaries.sort()
# ----> 3 salaries.avg()
#
# AttributeError: 'list' object has no attribute 'avg'

# %%
df['income'].plot()

# %% [markdown]
# ### 6. Are there any duplicate values in the dataset

# %% [markdown]
# #### How to generate random values

# %%
import random

# %%
random_values = random.randint(3,9)
random_values
# Out:
# 9

# %% [markdown]
# ####. How to drop null values from a dataframe

# %%
####. How to drop null values from a dataframe
df.dropna()
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %%
covid_table = pd.read_csv('covid-vaccination-vs-death_ratio.csv')

# %%
covid_table
# Out:
#        Unnamed: 0      country iso_code        date  total_vaccinations  \
# 0               0  Afghanistan      AFG  2021-05-11            504502.0
# 1               1  Afghanistan      AFG  2021-05-20            547901.0
# 2               2  Afghanistan      AFG  2021-05-24            573277.0
# 3               3  Afghanistan      AFG  2021-05-26            590454.0
# 4               4  Afghanistan      AFG  2021-05-27            593313.0
# ...           ...          ...      ...         ...                 ...
# 32906       32906     Zimbabwe      ZWE  2022-03-25           8691642.0
# 32907       32907     Zimbabwe      ZWE  2022-03-26           8791728.0
# 32908       32908     Zimbabwe      ZWE  2022-03-27           8845039.0
# 32909       32909     Zimbabwe      ZWE  2022-03-28           8934360.0
# 32910       32910     Zimbabwe      ZWE  2022-03-29           9039729.0
#
#        people_vaccinated  people_fully_vaccinated  New_deaths  population  \
# ...
